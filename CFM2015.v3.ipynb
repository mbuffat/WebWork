# %%
# %matplotlib inline
# %autosave 300
from IPython.display import display
from IPython.display import Image, HTML
from IPython.display import IFrame,YouTubeVideo
display(HTML(open('style.css').read()))
# Out:
# Autosaving every 300 seconds
# <style>
# /* font awesome */
# /*
#   .icon-university{position:relative}
#   .icon-university:before{content:"\f19c"}
# */
# @import url(//netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.min.css);
# /* style beige.css */
# .reveal h1 {
#   text-shadow: none;
# }
# #talk-title
# {
#   text-align: center;
#   font-size: 180%;
# }
#
# #talk-subtitle
# {
#   text-align: center;
#   font-size: 160%;
# }
# </style>

# %% [markdown]
# <h2><div id="talk-title">"Webwork" et "Ipython"<br>
# retour d'expériences</div></h2>
# <center>
# <br>
# <img src="Figures/webwork0.png" alt="webwork" style="display:inline;width:400px;" /><br>
# <img src="Figures/Ipython.jpeg" alt="ipython" style="display:inline;width:400px;" />
# </center>
# <br>
#
#
# <p style="text-align: left;"><i class="icon-user icon-2x"> <a href="http://ufrmeca.univ-lyon1.fr/~buffat">Marc BUFFAT</a> @ univ-lyon1.fr</i></p>
#
# <p style="text-align: left;"><i class="icon-building icon-2x"> dpt Mécanique, université Lyon 1</i></p>

# %% [markdown]
# <h1><div id="talk-title">Remerciement</div></h1>
# <br>
# <p style="text-align: left;"><i class="icon-group icon-2x"> projet **WebWork** à l'UCB Lyon 1</i></p>
# Claude Inserra, Pierre Valiorgue, John Sundar, Morgane Bergot, Antoine Cazes, ..
#
# <p style="text-align: left;"><i class="icon-hand-right icon-2x"><a href="http://webwork.maa.org">WebWork: http://webwork.maa.org</a></i></p>
# Pr. **Michael Gage**, department of mathematics, university of Rochester
#
# <p style="text-align: left;"><i class="icon-hand-right icon-2x"><a href="http://ipython.org">Ipython notebook: http://ipython.org</a></i></p>
# **Fernando Pérez**, Lawrence Berkeley National Laboratory

# %% [markdown]
# <h1><div id="talk-title">Contexte</div></h1>
#
# - Formation en présentiel en Licence / Master  Mécanique Energétique
#
# - Enseignements de Mécanique (fluide/solide) et Méthodes numériques
#
# - portail pédagogique: http://ufrmeca.univ-lyon1.fr/moodle

# %%
IFrame("http://ufrmeca.univ-lyon1.fr/moodle?lang=fr",width="100%",height=400)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="http://ufrmeca.univ-lyon1.fr/moodle?lang=fr"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
Image(filename="Figures/LicenceMasterMEGA.png",width="100%")

# %% [markdown]
# <h1><div id="talk-subtitle">Enseignement en science</div></h1>
# <br>
# <h2><center>*Mathematics (and Science) is not a spectator sport*</center></h2>
#
# ## Constat sur l'enseignement à l'université
#
# - étudiants de formation très disparate avec un manque de méthode de travail
# - peu de maîtrise de l'outil mathématique, et de la programmation scientifique

# %% [markdown]
# ## Besoin en enseignement
#  - apprentissage interactif par la pratique
#     * $\Rightarrow$ exercices pour les étudiants
#     * $\Rightarrow$ résolution de  problème pour acquérir méthode et formalisme
#  - acces en dehors des heures encadrées
#  - utilisation du Web

# %% [markdown]
# <h1><div id="talk-subtitle">Outils disponibles</div></h1>
#
# <p style="text-align: left;"><i class="icon-windows icon-2x"> Logiciels sur </i><i class="icon-laptop icon-3x"></i></p>
#
# mise à disposition en salle de TP (libre service)
#
# - Matlab/ Maple/ Comsol/ ....
# - logiciels propriétaires (licence)
# - nécéssite une installation
#
# <p style="text-align: left;"><i class="icon-linux icon-2x"> Outils Web 2.0 </i><i class="icon-cloud icon-3x"></i></p>
#
# logiciels libres
#
# - Webwork
# - IPython notebook
# - Sage / SageCell
# - aucune installation (navigateur/tablette/smartphone)

# %% [markdown]
# <h1><div id="talk-subtitle">WebWork</div></h1>
# <h2><center>http://webwork.maa.org</center></h2>
# <center><img src="Figures/webwork_rectangle.png" alt="Webwork" />
# </center>
# ##système de devoirs en ligne en mathématique
#
#
# - développé à l'université de Rochester
# - très utilisé dans les enseignements de Mathématique
# <img src="Figures/MAA.jpeg" width=200/>
# - énorme bibliothèque d'exercices: $\approx 20 000$<br>
# algèbre, probabilité, calculus, equa. diff., algèbre linéaire, analyse complexe,..
#
# - système ouvert (libre) et interfaçable (LMS Moodle, SageCell)

# %% [markdown]
# <h1><div id="talk-subtitle">Intérêts de WebWork<br>
# <img src="Figures/test.jpg" alt="Webwork" style="height:200px;" /></div></h1>
# ## rendre les devoirs à la maison plus efficaces
#
# - réponse immédiate pour les étudiants
#
# - version individualisée des devoirs
#
# - notation automatique
#
# ##interface WEB
# <a href="http://ufrmeca.univ-lyon1.fr/moodle">http://ufrmeca.univ-lyon1.fr/moodle</a>

# %%
IFrame("http://ufrmeca.univ-lyon1.fr/moodle/course/view.php?id=2",width="100%",height="800")
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://ufrmeca.univ-lyon1.fr/moodle/course/view.php?id=2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <center><img src="Figures/webwork_rectangle.png" alt="Webwork" /></center>
# <h2> version papier (PDF) des problèmes </h2>

# %%
IFrame("Figures/AeroDynL3.buffat.chap0.pdf",width="100%",height=600)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="Figures/AeroDynL3.buffat.chap0.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <center><img src="Figures/webwork_rectangle.png" alt="Webwork" /></center>
# ##Entrée des réponses
# <img src="Figures/AerodynL3webwork2.png" style="display:inline;width:800px;"/>

# %% [markdown]
# <center><img src="Figures/webwork_rectangle.png" alt="Webwork" /></center>
# ## Validation des réponses
# <img src="Figures/AerodynL3webwork3.png" style="display:inline;width:800px;"/>

# %% [markdown]
# <h1><div id="talk-title">Pourquoi <img style="display:inline; width:250px;"src="Figures/python.png"></div></h1>

# %% [markdown]
# <p style="text-align: left;"><i class="icon-smile icon-2x"> Pour les Monty Python</i></p>
# <img style="display:inline; width:600px;"src="Figures/ministry-of-silly-walks.jpg">

# %% [markdown]
# <p style="text-align: left;"><i class="icon-smile icon-2x"> Caractéristiques du langage</i></p>
#
# - Python est un **excellent langage** pour l'apprentissage de la programmation scientifique, qui remplace avantageusement **MatLab**
#
# - très large domaine applicatifs

# %% [markdown]
# <h1><div id="talk-title">Pourquoi <img style="float:center; display:inline; width:250px;" src='Figures/ipynblogo.png'></div></h1>
#
# <p style="text-align: left;"><i class="icon-check icon-2x"> Environnement de programmation</i></p>
#
# - Python, R, Ruby, bash
#
# <p style="text-align: left;"><i class="icon-check icon-2x"> Utilise un navigateur Web</i></p>
#
# - Markdown + HTML, texte + $\LaTeX$ + image + vidéo
#
# <p style="text-align: left;"><i class="icon-check icon-2x">  Python scientifique </i></p>
#
# - Matplotlib, Numpy, Scipy
#
# <p style="text-align: left;"><i class="icon-check icon-2x">  Présentation scientifique interactive </i></p>
#
# <p style="text-align: left;"><i class="icon-check icon-2x">  Serveur web Jupyter </i></p>
#
# <br>
#
# <center>**Notebook Ipython:** <a href="http://localhost:8900/notebooks/COURS_ALGORITHME/Swinging_pendulum.ipynb">  "Swinging pendulum"</a> et <a href="http://localhost:8900/notebooks/EltFinis2D/Laplace2D.ipynb">"Elements finis"</a></center>

# %% [markdown]
# <h1><div id="talk-title">INPROS</div></h1>
#
# <img src="Figures/logo_trans.png" alt="INPROS" width="200"/>
#
# **INtroduction à la PROgrammation Scientifique**
#
# Prototype de FLOT <a href='http://inpros.univ-lyon1.fr'>http://inpros.univ-lyon1.fr</a>
#
# ## Projet collaboratif
# - objectif: apprentissage d'une méthodologie en programmation scientifique
# - cours d'initiation (public très large)
# - cours interactif avec mise en pratique
# - accessible à partir d'un simple navigateur
# - utilise Webwork, Sagecell, Ipython

# %%
url='http://inpros.univ-lyon1.fr'
IFrame(url,width="100%",height=500)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="http://inpros.univ-lyon1.fr"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <h1><div id="talk-title">Conclusion</div></h1>
# ## Webwork/Ipython notebook en L3/M1 méca.
# - étudiants travaillent à leur rythme
# - plusieurs tentatives (80 à 100% réussite)
# - mise en place  L1 portail PCSI
# - projet FLOT INPROS

# %% [markdown]
# ## Difficultés
# - temps de mise en oeuvre
# - valorisation pour les enseignants

# %% [markdown]
# <h1><div id="talk-title">Merci de votre attention !!</div></h1>
# <center>
# <img src="Figures/face_question_mark1.jpg" alt="Questions" style="width:200px;"/><br>
# </center>
# <h2><div id="talk-subtitle">Des questions ?</div></h2>
